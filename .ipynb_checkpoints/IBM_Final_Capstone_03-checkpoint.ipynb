# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# ## Description

# %% [markdown]
# <font size="3">**Context**</font><br>
# It is important that credit card companies are able to recognize fraudulent credit card transactions so that customers are not charged for items that they did not purchase.
#
# <font size="3">**Content**</font><br>
# The datasets contains transactions made by credit cards in September 2013 by european cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning. Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.
#
# <font size="3">**Inspiration**</font><br>
# Identify fraudulent credit card transactions.
#
# Given the class imbalance ratio, we recommend measuring the accuracy using the Area Under the Precision-Recall Curve (AUPRC). Confusion matrix accuracy is not meaningful for unbalanced classification.
#
# <font size="3">**Acknowledgements**</font><br>
# The dataset has been collected and analysed during a research collaboration of Worldline and the Machine Learning Group (http://mlg.ulb.ac.be) of ULB (Université Libre de Bruxelles) on big data mining and fraud detection.
# More details on current and past projects on related topics are available on https://www.researchgate.net/project/Fraud-detection-5 and the page of the DefeatFraud project
#
# Please cite the following works:
#
# Andrea Dal Pozzolo, Olivier Caelen, Reid A. Johnson and Gianluca Bontempi. Calibrating Probability with Undersampling for Unbalanced Classification. In Symposium on Computational Intelligence and Data Mining (CIDM), IEEE, 2015
#
# Dal Pozzolo, Andrea; Caelen, Olivier; Le Borgne, Yann-Ael; Waterschoot, Serge; Bontempi, Gianluca. Learned lessons in credit card fraud detection from a practitioner perspective, Expert systems with applications,41,10,4915-4928,2014, Pergamon
#
# Dal Pozzolo, Andrea; Boracchi, Giacomo; Caelen, Olivier; Alippi, Cesare; Bontempi, Gianluca. Credit card fraud detection: a realistic modeling and a novel learning strategy, IEEE transactions on neural networks and learning systems,29,8,3784-3797,2018,IEEE
#
# Dal Pozzolo, Andrea Adaptive Machine learning for credit card fraud detection ULB MLG PhD thesis (supervised by G. Bontempi)
#
# Carcillo, Fabrizio; Dal Pozzolo, Andrea; Le Borgne, Yann-Aël; Caelen, Olivier; Mazzer, Yannis; Bontempi, Gianluca. Scarff: a scalable framework for streaming credit card fraud detection with Spark, Information fusion,41, 182-194,2018,Elsevier
#
# Carcillo, Fabrizio; Le Borgne, Yann-Aël; Caelen, Olivier; Bontempi, Gianluca. Streaming active learning strategies for real-life credit card fraud detection: assessment and visualization, International Journal of Data Science and Analytics, 5,4,285-300,2018,Springer International Publishing
#
# Bertrand Lebichot, Yann-Aël Le Borgne, Liyun He, Frederic Oblé, Gianluca Bontempi Deep-Learning Domain Adaptation Techniques for Credit Cards Fraud Detection, INNSBDDL 2019: Recent Advances in Big Data and Deep Learning, pp 78-88, 2019
#
# Fabrizio Carcillo, Yann-Aël Le Borgne, Olivier Caelen, Frederic Oblé, Gianluca Bontempi Combining Unsupervised and Supervised Learning in Credit Card Fraud Detection Information Sciences, 2019

# %% [markdown]
# ---

# %% [markdown]
# # Description of the problem

# %% [markdown]
# Credit card fraud is an inclusive term for fraud committed using a payment card, such as a credit card or debit card. The purpose may be to obtain goods or services, or to make payment to another account which is controlled by a criminal. The Payment Card Industry Data Security Standard (PCI DSS) is the data security standard created to help businesses process card payments securely and reduce card fraud.
#
# Credit card fraud can be authorised, where the genuine customer themselves processes a payment to another account which is controlled by a criminal, or unauthorised, where the account holder does not provide authorisation for the payment to proceed and the transaction is carried out by a third party. In 2018, unauthorised financial fraud losses across payment cards and remote banking totalled £844.8 million in the United Kingdom. Whereas banks and card companies prevented £1.66 billion in unauthorised fraud in 2018. That is the equivalent to £2 in every £3 of attempted fraud being stopped.
#
# Credit cards are more secure than ever, with regulators, card providers and banks taking considerable time and effort to collaborate with investigators worldwide to ensure fraudsters aren't successful. Cardholders' money is usually protected from scammers with regulations that make the card provider and bank accountable. The technology and security measures behind credit cards are becoming increasingly sophisticated making it harder for fraudsters to steal money.
#
# From Wikipedia.
#
# This analysis can help for the banks to detect the fraud credit card.

# %% [markdown]
# ---

# %% [markdown]
# # Description of the data

# %% [markdown]
# Unfortunately, I cannot describe the data, because they are secret! However with these data we are able to find a solution for this kind of problem.

# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix,classification_report
from sklearn import metrics

# %% [markdown]
# ---

# %% [markdown]
# # Check Dataframe

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# **Let's get some information about the Dataframe**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# # Data Quality check !

# %% [markdown]
# **Test for Nan values**

# %%
round(10000*df.isnull().sum()/len(df),2)
# Out:
# Time      0.0
# V1        0.0
# V2        0.0
# V3        0.0
# V4        0.0
# V5        0.0
# V6        0.0
# V7        0.0
# V8        0.0
# V9        0.0
# V10       0.0
# V11       0.0
# V12       0.0
# V13       0.0
# V14       0.0
# V15       0.0
# V16       0.0
# V17       0.0
# V18       0.0
# V19       0.0
# V20       0.0
# V21       0.0
# V22       0.0
# V23       0.0
# V24       0.0
# V25       0.0
# V26       0.0
# V27       0.0
# V28       0.0
# Amount    0.0
# Class     0.0
# dtype: float64

# %% [markdown]
# **There are no missing values !**

# %%
df2 = df.copy()
df2.drop_duplicates(inplace=True)

# %%
df2.shape
# Out:
# (283726, 31)

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# **There were some duplicates in the dataframe! Remove them!**

# %%
df= df2.copy()

# %%
df.shape
# Out:
# (283726, 31)

# %% [markdown]
# ---

# %% [markdown]
# # Visualization !

# %%
plt.figure(figsize=(10,8))
sns.set_style("darkgrid")
ax = sns.countplot(x='Class', data = df, palette='deep')
plt.title("Class Distribution\nFraud-->1, No Fraud-->0", fontsize=16)
plt.xlabel("Class",size=14)
plt.ylabel("Count",size=14)
ax.set_yscale('log')
plt.savefig("Class Distribution.png")
plt.show()

# %% [markdown]
# **As we can see, the different between Fraud and no Fraud is so huge! I will balance it for machine learning later**

# %%
df.Class.value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
(473/len(df))*100
# Out:
# 0.1667101358352777

# %% [markdown]
# **The fraud transactions are almost nothing!**

# %%
plt.figure(figsize=(10,8))
sns.set_style("darkgrid")
ax = sns.distplot(df["Amount"], bins=100,color = 'orange')
plt.title("Amount Distribution", fontsize=16)
plt.xlabel("Amount",size=14)
plt.savefig("Amount Distribution.png")
plt.show()

# %% [markdown]
# **In this distribution, the values are concentrated in the begining of Amount.**

# %%
plt.figure(figsize=(10,8))
sns.set_style("darkgrid")
ax = sns.distplot(df["Time"], bins=100, color='red', norm_hist = True)
ax.set_title("Time Distribution", fontsize=16)
plt.xlabel("Time",size=14)
plt.savefig("Time Distribution.png")
plt.show()

# %% [markdown]
# **Before 25000 and between 100000 and 125000 are Transactions**

# %%
df_ = df[df['Class']==1]

# %%
df_['Amount'].value_counts()
# Out:
# 1.00      105
# 99.99      27
# 0.00       25
# 0.76       17
# 0.77       10
#          ...
# 104.03      1
# 925.31      1
# 323.77      1
# 57.73       1
# 175.90      1
# Name: Amount, Length: 259, dtype: int64

# %%
df_['Amount'].max() # Find the max value in Fraud section (1)
# Out:
# 2125.87

# %%
plt.figure(figsize=(20,8))
sns.set_style("darkgrid")
color_dict = dict({0:'white',1:'red'})
#ax = sns.scatterplot(data = df, x ='Time', y='Amount', hue='Class', palette=color_dict, alpha=0.5)
ax = sns.scatterplot(data=df[df.Class == 0], x='Time', y='Amount', hue='Class', palette=color_dict,  alpha=0.2)
sns.scatterplot(data=df[df.Class == 1], x='Time', y='Amount', hue='Class', palette=color_dict,  alpha=1, ax=ax)
plt.title("Fraud Distribution based on the Time", fontsize=16)
plt.xlabel("Time",size=14)
plt.ylabel("Amount",size=14)
ax.set(ylim=(0, 3000))
plt.savefig("Fraud Distribution based on the Time.png")
plt.show()

# %% [markdown]
# **Before 25000 and between 100000 and 125000 are less Fraud transaction. it is related to the "Time distribution".**

# %%
plt.figure(figsize=(45,15))
sns.heatmap(df.corr(), annot = True, cmap = "coolwarm")
plt.savefig("Correlation.png")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Methodology

# %% [markdown]
# Results until here based on the analysis:
# - The fraud distribution is not so high by the amount of fraud, if we compare the global picture. The maximum amount is 2126 dollar.
# - The percentage of fraud is 0,17!
# - The fraud transactions follow the normal transactions, so we cannot find a specific time to fraud.
#
#
# In the further I am going to use some machine learning models and deep learning model to find a good solution for this problem. With Them help the earlier detection can be faster.

# %% [markdown]
# ---

# %% [markdown]
# # Scaling and Balanced DF for ML

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm_scaler = MinMaxScaler()

# %%
df['s_time'] = mm_scaler.fit_transform(df['Time'].values.reshape(-1,1)) 
df['s_amount'] = mm_scaler.fit_transform(df['Amount'].values.reshape(-1,1))

# %% [markdown]
# **Other columns are already scaled!**

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V23       V24       V25       V26       V27  \
# 0  0.098698  0.363787  ... -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1  0.085102 -0.255425  ...  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2  0.247676 -1.514654  ...  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3  0.377436 -1.387024  ... -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4 -0.270533  0.817739  ... -0.137458  0.141267 -0.206010  0.502292  0.219422
#
# ...

# %%
df.drop(['Time','Amount'], axis=1, inplace = True)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.098698  0.363787  0.090794  ...  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  0.207643  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  0.753074  ...  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Class    s_time  s_amount
# ...

# %%
df_1 = df[df['Class']==1]

# %%
df_1.shape
# Out:
# (473, 31)

# %%
df_2 = df[df['Class']==0].sample(n=473)

# %%
df_2.shape
# Out:
# (473, 31)

# %%
dfnew = pd.concat([df_1,df_2])

# %%
dfnew.head()
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 541  -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 623  -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 4920 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 6108 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 6329  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
#
#             V8        V9       V10  ...       V22       V23       V24  \
# 541   1.391657 -2.770089 -2.772272  ... -0.035049 -0.465211  0.320198
# 623  -0.067794 -0.270953 -0.838587  ...  0.435477  1.375966 -0.293803
# 4920 -0.399147 -0.238253 -1.525412  ... -0.932391  0.172726 -0.087330
# 6108 -0.248778 -0.247768 -4.801637  ...  0.176968 -0.436207 -0.053502
# 6329 -0.496358 -1.282858 -2.447469  ... -0.704181 -0.656805 -1.632653
#
#            V25       V26       V27       V28  Class    s_time  s_amount
# ...

# %%
dfnew.tail()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 212704 -0.283613  0.936636 -0.505754 -1.293424  1.074370 -1.670357  1.874728
# 154419 -0.480842  1.464343 -0.530064 -0.706013  1.158876 -0.334749  0.931267
# 3715    1.070801  0.041820  0.667713  1.023570 -0.486857 -0.196153 -0.210674
# 54560   1.210674 -1.316084  0.959650 -1.950240 -1.850219 -0.129266 -1.299443
# 244656  0.077037  0.184788 -0.061550 -1.926667  0.087273 -1.247741  1.128746
#
#               V8        V9       V10  ...       V22       V23       V24  \
# 212704 -0.553407 -0.287030 -0.963096  ...  0.694769 -0.395522  0.006868
# 154419 -0.199240  1.766237  0.110245  ... -1.026840  0.065225  0.166291
# 3715    0.215182  0.065441  0.126958  ... -0.700006  0.187243  0.119866
# 54560   0.287351  0.901571 -0.268783  ... -0.337318  0.096111  0.204396
# 244656 -0.461493 -1.607248  0.061539  ...  0.572605  0.187286  0.001136
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.set_style("darkgrid")
ax = sns.countplot(x='Class', data = dfnew, palette='deep')
plt.title("Class Distribution\nFraud-->1, No Fraud-->0", fontsize=16)
plt.xlabel("Class",size=14)
plt.ylabel("Count",size=14)
plt.savefig("Class Distribution Balanced.png")
plt.show()

# %%
X = dfnew.drop(['Class'],axis=1)

# %%
y = dfnew['Class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# %% [markdown]
# ---

# %% [markdown]
# # Machine Learning Models

# %% [markdown]
# ---

# %% [markdown]
# ## K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k = 2
#Train Model and Predict  
neighboor = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
neighboor
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
predKNN = neighboor.predict(X_test)

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neighboor.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, predKNN))
# Out:
# Train set Accuracy:  0.9523809523809523
# Test set Accuracy:  0.9157894736842105

# %% [markdown]
# ### Find the best Parameter

# %%
Ks = 50
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))

for n in range(1,Ks):
    
    #Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

mean_acc
# Out:
# array([0.9       , 0.91578947, 0.91052632, 0.90526316, 0.91052632,
#        0.91578947, 0.91578947, 0.91052632, 0.91578947, 0.90526316,
#        0.90526316, 0.90526316, 0.91052632, 0.90526316, 0.90526316,
#        0.90526316, 0.90526316, 0.9       , 0.9       , 0.9       ,
#        0.9       , 0.9       , 0.9       , 0.89473684, 0.89473684,
#        0.89473684, 0.89473684, 0.89473684, 0.89473684, 0.89473684,
#        0.89473684, 0.89473684, 0.89473684, 0.89473684, 0.89473684,
#        0.89473684, 0.89473684, 0.89473684, 0.89473684, 0.89473684,
#        0.89473684, 0.89473684, 0.9       , 0.89473684, 0.9       ,
#        0.89473684, 0.9       , 0.89473684, 0.89473684])

# %%
np.argmax(mean_acc) #--> k=2
# Out:
# 1

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, predKNN))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        88
#            1       1.00      0.84      0.91       102
#
#     accuracy                           0.92       190
#    macro avg       0.92      0.92      0.92       190
# weighted avg       0.93      0.92      0.92       190

# %% [markdown]
# ### Confusion Matrix

# %%
cm=confusion_matrix(y_test,predKNN)
conf_matrix=pd.DataFrame(data=cm,columns=['Predicted:0','Predicted:1'],index=['Actual:0','Actual:1'])
plt.figure(figsize = (8,5))
plt.title("K nearest Neighbors' Confusion Matrix", size=16)
plt.savefig("K nearest Neighbors' Confusion Matrix.png")
sns.heatmap(conf_matrix, annot=True,fmt='d',cmap="coolwarm")
plt.savefig("K nearest Neighbors' Confusion Matrix.png")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dectree = DecisionTreeClassifier(criterion="entropy")
dectree
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dectree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
predtree = dectree.predict(X_test)

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dectree.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, predtree))
# Out:
# Train set Accuracy:  1.0
# Test set Accuracy:  0.9105263157894737

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, predtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91        88
#            1       0.93      0.90      0.92       102
#
#     accuracy                           0.91       190
#    macro avg       0.91      0.91      0.91       190
# weighted avg       0.91      0.91      0.91       190

# %% [markdown]
# ### Confusion Matrix

# %%
cm=confusion_matrix(y_test,predtree)
conf_matrix=pd.DataFrame(data=cm,columns=['Predicted:0','Predicted:1'],index=['Actual:0','Actual:1'])
plt.figure(figsize = (8,5))
plt.title("Decision Tree's Confusion Matrix", size=16)
sns.heatmap(conf_matrix, annot=True,fmt='d',cmap="coolwarm")
plt.savefig("Decision Tree's Confusion Matrix.png")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn import svm
svm = svm.SVC(kernel='rbf')
svm.fit(X_train, y_train)
# Out:
# SVC()

# %%
predsvm = svm.predict(X_test)

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, svm.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, predsvm))
# Out:
# Train set Accuracy:  0.9431216931216931
# Test set Accuracy:  0.9

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, predsvm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.99      0.90        88
#            1       0.99      0.82      0.90       102
#
#     accuracy                           0.90       190
#    macro avg       0.91      0.91      0.90       190
# weighted avg       0.91      0.90      0.90       190

# %% [markdown]
# ### Confusion Matrix

# %%
cm=confusion_matrix(y_test,predsvm)
conf_matrix=pd.DataFrame(data=cm,columns=['Predicted:0','Predicted:1'],index=['Actual:0','Actual:1'])
plt.figure(figsize = (8,5))
plt.title("SVM's Confusion Matrix", size=16)
sns.heatmap(conf_matrix, annot=True,fmt='d',cmap="coolwarm")
plt.savefig("SVM's Confusion Matrix.png")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(C=0.01, solver='liblinear')

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.01, solver='liblinear')

# %%
predlr = lr.predict(X_test)

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, lr.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, predlr))
# Out:
# Train set Accuracy:  0.9470899470899471
# Test set Accuracy:  0.9157894736842105

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, predlr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.91        88
#            1       0.98      0.86      0.92       102
#
#     accuracy                           0.92       190
#    macro avg       0.92      0.92      0.92       190
# weighted avg       0.92      0.92      0.92       190

# %% [markdown]
# ### Confusion Matrix

# %%
cm=confusion_matrix(y_test,predlr)
conf_matrix=pd.DataFrame(data=cm,columns=['Predicted:0','Predicted:1'],index=['Actual:0','Actual:1'])
plt.figure(figsize = (8,5))
plt.title("Logistic Regression's Confusion Matrix", size=16)
sns.heatmap(conf_matrix, annot=True,fmt='d',cmap="coolwarm")
plt.savefig("Logistic Regression's Confusion Matrix.png")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Deep Learning Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential()

# input layer
model.add(Dense(78,  activation='relu'))
model.add(Dropout(0.5))

# hidden layer
model.add(Dense(39, activation='relu'))
model.add(Dropout(0.5))

# hidden layer
model.add(Dense(19, activation='relu'))
model.add(Dropout(0.4))

# hidden layer
model.add(Dense(9, activation='relu'))
model.add(Dropout(0.4))

# output layer
model.add(Dense(units=1,activation='sigmoid'))

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=250,
          batch_size=256,
          validation_data=(X_test, y_test),
          callbacks=[early_stop]
          )
# Out:
# Epoch 1/250
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 3/3 [==============================] - 0s 48ms/step - loss: 0.8483 - val_loss: 0.5290
# Epoch 2/250
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7891 - val_loss: 0.5238
# Epoch 3/250
# ...

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()

# %%
dlpred = model.predict_classes(X_test)
# Out:
# WARNING:tensorflow:From <ipython-input-83-2936187202a1>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, dlpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.92        88
#            1       0.99      0.85      0.92       102
#
#     accuracy                           0.92       190
#    macro avg       0.92      0.92      0.92       190
# weighted avg       0.93      0.92      0.92       190

# %% [markdown]
# ### Confusion Matrix

# %%
cm=confusion_matrix(y_test,dlpred)
conf_matrix=pd.DataFrame(data=cm,columns=['Predicted:0','Predicted:1'],index=['Actual:0','Actual:1'])
plt.figure(figsize = (8,5))
plt.title("Deep Learning's Confusion Matrix", size=16)
sns.heatmap(conf_matrix, annot=True,fmt='d',cmap="coolwarm")
plt.savefig("Deep Learning's Confusion Matrix.png")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Results and Discussion

# %% [markdown]
# Based on the Models and analysis:
# - We can predict the Fraud credict card with around 90% sure.
# - The fraud distribution is not so high by the amount of fraud, if we compare the global picture. The maximum amount is 2126 dollar.
# - The percentage of fraud is 0,17!
# - The fraud transactions follow the normal transactions, so we cannot find a specific time to fraud.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Purpose of this project was to identify the Fraud Credit Cards. As we can see,firstly, we have found some anomalies with the simple visualizations. After we had taken into consideration these information, The models have been built and they are given around 90% sure prediction for the next test data.
